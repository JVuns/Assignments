# %%
# Import stuff
import pandas as pd
filepath = "D:/Ran/activity.csv"

# %%
# A
df = pd.read_csv(str(filepath))
print(round(df["steps"].sum()/df.iloc[:,1].nunique()))
# Out:
# 9354.0

# %%
df = pd.read_csv(str(filepath))
# my_histogram = df['steps'].groupby(df['date']).sum().plot(kind="hist")
# hist = df.hist(column="steps", by="date")
# df.hist(bins = 100)
plt.show()
# my_histogram.hist()

# %%
print(df['steps'].groupby(df['date']).median())
print(df['steps'].groupby(df['date']).mean())
# Out:
# date
# 01/10/2012    NaN
# 01/11/2012    NaN
# 02/10/2012    0.0
# 02/11/2012    0.0
# 03/10/2012    0.0
#              ...
# 29/10/2012    0.0
# 29/11/2012    0.0
# 30/10/2012    0.0
# 30/11/2012    NaN
# 31/10/2012    0.0
# Name: steps, Length: 61, dtype: float64
# date
# 01/10/2012          NaN
# 01/11/2012          NaN
# 02/10/2012     0.437500
# 02/11/2012    36.805556
# 03/10/2012    39.416667
#                 ...
# 29/10/2012    17.423611
# 29/11/2012    24.468750
# 30/10/2012    34.093750
# 30/11/2012          NaN
# 31/10/2012    53.520833
# Name: steps, Length: 61, dtype: float64
