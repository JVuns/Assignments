# %%
import numpy as np
import pandas as pd
import datetime
from matplotlib import pyplot as plt
import time
pd.set_option("display.max_rows", None, "display.max_columns", None)
filepath = "D:/Ran/activity.csv"

# %%
df = pd.read_csv(filepath)

interval = []
steps = []

for x in df['interval'].unique():
    interval.append(x)
    steps.append(df.loc[df['interval']==x, 'steps'].dropna().mean())

df = pd.DataFrame({"Interval": interval, "Steps": steps})
df.plot.line(x="Interval", y="Steps")
plt.title("Average number of steps in 5-minute intervals")
plt.xlabel("Time")
plt.ylabel("Average steps")
plt.xticks(np.linspace(0, 2355, 15))
plt.show()
print(f"Interval with max average step: {df.loc[df['Steps']==df['Steps'].max(), 'Interval'].item()}.")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'interval'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-aa88ec191221> in <module>
#      15 plt.xticks(np.linspace(0, 2355, 15))
# ...
